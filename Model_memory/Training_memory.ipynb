# %%
import pandas as pd
import numpy as np

# %%
mm1 = pd.read_csv('playing_memory_ep30.csv')
mm2 = pd.read_csv('playing_memory_ep60.csv')
mm3 = pd.read_csv('playing_memory_ep100.csv')
mm4 = pd.read_csv('playing_memory_ep140.csv')
mm5 = pd.read_csv('playing_memory_ep180.csv')
mm6 = pd.read_csv('playing_memory_ep200.csv')

# %%
mm = pd.concat([mm1, mm2, mm3, mm4, mm5, mm6], ignore_index=True)
mm
# Out:
#        episode  cart_position  cart_velocity  pole_angle  \
# 0            0       0.013870       0.026208    0.027376
# 1            0       0.014394       0.220927    0.028038
# 2            0       0.018813       0.415638    0.023022
# 3            0       0.027126       0.220200    0.012332
# 4            0       0.031530       0.415143    0.007639
# ...        ...            ...            ...         ...
# 63717      199      -2.232491      -2.119255   -0.038170
# 63718      199      -2.274876      -1.923694   -0.007699
# 63719      199      -2.313350      -2.118715    0.016685
# 63720      199      -2.355725      -1.923800    0.046874
# 63721      199      -2.394201      -1.729312    0.071315
#
#        pole_angular_velocity  action  reward  new_cart_position  \
# 0                   0.033123       1     1.0           0.014394
# 1                  -0.250798       1     1.0           0.018813
# 2                  -0.534507       0     1.0           0.027126
# ...

# %%
mm.to_csv('playing_memory_200.csv', index=False)

# %%
mm240 = pd.read_csv('playing_memory_ep240.csv')
mm280 = pd.read_csv('playing_memory_ep280.csv')
mm320 = pd.read_csv('playing_memory_ep320.csv')
mm360 = pd.read_csv('playing_memory_ep360.csv')
mm400 = pd.read_csv('playing_memory_ep400.csv')

# %%
memory_400 = pd.concat([mm, mm240, mm280, mm320, mm360, mm400], ignore_index=True)
memory_400.to_csv('playing_memory_400.csv', index=False)

# %%
mm440 = pd.read_csv('playing_memory_ep440.csv')
mm480 = pd.read_csv('playing_memory_ep480.csv')
mm520 = pd.read_csv('playing_memory_ep520.csv')

# %%
memory = pd.concat([memory_400, mm440, mm480, mm520], ignore_index=True)

# %%
memory.to_csv('playing_memory_520.csv', index=False)

# %%
mm560 = pd.read_csv('playing_memory_ep560.csv')
mm600 = pd.read_csv('playing_memory_ep600.csv')
mm640 = pd.read_csv('playing_memory_ep640.csv')
mm680 = pd.read_csv('playing_memory_ep680.csv')

# %%
memory = pd.concat([memory, mm560, mm600, mm640, mm680], ignore_index=True)

# %%
memory.to_csv('playing_memory_680.csv', index=False)

# %%
len(memory)
# Out:
# 217181
