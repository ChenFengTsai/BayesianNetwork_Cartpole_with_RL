# %%
import pandas as pd
import numpy as np

# %%
mm1 = pd.read_csv('organized_training_memory_test_avg200.csv')
mm2 = pd.read_csv('organized_training_memory_ep30_59.csv')
mm3 = pd.read_csv('organized_training_memory_ep60_89.csv')
mm4 = pd.read_csv('organized_training_memory_ep90_109.csv')
mm5 = pd.read_csv('organized_training_memory_ep110_129.csv')

# %%
mm = pd.concat([mm1, mm2, mm3, mm4, mm5], ignore_index=True)
mm
# Out:
#        episode  cart_position  cart_velocity  pole_angle  \
# 0            0      -0.008641      -0.005579   -0.015901
# 1            0      -0.008752      -0.200469   -0.016661
# 2            0      -0.012762      -0.395349   -0.011669
# 3            0      -0.020669      -0.590305   -0.000929
# 4            0      -0.032475      -0.395170    0.015590
# ...        ...            ...            ...         ...
# 26712      129       0.128676       0.186645   -0.096644
# 26713      129       0.132409      -0.006970   -0.099944
# 26714      129       0.132270      -0.200528   -0.098031
# 26715      129       0.128259      -0.394129   -0.090927
# 26716      129       0.120376      -0.587871   -0.078618
#
#        pole_angular_velocity  action  reward  new_cart_position  \
# 0                  -0.038013       0     1.0          -0.008752
# 1                   0.249611       0     1.0          -0.012762
# 2                   0.536992       0     1.0          -0.020669
# ...

# %%
mm.to_csv('training_memory_eps130.csv', index=False)
